# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'MRI'
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality)
# Out:
# 1/3 Correction with CA: None
# Cross-validating...
# done.
# n =  67 mean age =  73.84 5.77
# Bias between chronological age and BPAD eliminated: False (r = -0.8413842050331831 p = 4.95034603003821e-19 )
# Cross-validating...
# done.
# n =  74 mean age =  74.04 5.66
# Bias between chronological age and BPAD eliminated: False (r = -0.8468031925067422 p = 2.003682712512664e-21 )
# Cross-validating...
# done.
# n =  72 mean age =  73.92 6.0
# Bias between chronological age and BPAD eliminated: False (r = -0.8746243737889295 p = 1.0559469001265493e-23 )
# Cross-validating...
# done.
# n =  73 mean age =  73.64 5.89
# Bias between chronological age and BPAD eliminated: False (r = -0.8654386543229498 p = 5.308468054940201e-23 )
# Cross-validating...
# done.
# n =  71 mean age =  73.54 6.06
# Bias between chronological age and BPAD eliminated: False (r = -0.8854736483145175 p = 1.1650394250067478e-24 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  3.884818  0.353912   0.276335   svm
# 1      1  3.718382  0.363920  -0.472125   svm
# 2      2  4.048483  0.275335  -0.142055   svm
# 3      3  3.998164  0.264116  -0.504907   svm
# 4      4  4.174421  0.242670  -0.370166   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  3.964854  0.299991  -0.242584
# std    1.581139  0.172609  0.055170   0.322941
# min    0.000000  3.718382  0.242670  -0.504907
# 25%    1.000000  3.884818  0.264116  -0.472125
# 50%    2.000000  3.998164  0.275335  -0.370166
# 75%    3.000000  4.048483  0.353912  -0.142055
# max    4.000000  4.174421  0.363920   0.276335
# 2/3 Correction with CA: True
# Cross-validating...
# done.
# n =  67 mean age =  73.84 5.77
# Bias between chronological age and BPAD eliminated: True (r = 0.11656517143703751 p = 0.3475362828424253 )
# Cross-validating...
# done.
# n =  74 mean age =  74.04 5.66
# Bias between chronological age and BPAD eliminated: True (r = 0.19819759114377367 p = 0.09049900416751483 )
# Cross-validating...
# done.
# n =  72 mean age =  73.92 6.0
# Bias between chronological age and BPAD eliminated: True (r = -0.08303641675470172 p = 0.4880240391198243 )
# Cross-validating...
# done.
# n =  73 mean age =  73.64 5.89
# Bias between chronological age and BPAD eliminated: True (r = 0.044991542956979436 p = 0.7054568885924817 )
# Cross-validating...
# done.
# n =  71 mean age =  73.54 6.06
# Bias between chronological age and BPAD eliminated: True (r = -0.10744948551171314 p = 0.3724461195696861 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.131202  0.796745   0.648275   svm
# 1      1  1.814096  0.812663   0.257237   svm
# 2      2  1.937035  0.828171   0.128670   svm
# 3      3  1.963587  0.812780  -0.371466   svm
# 4      4  1.958331  0.830779  -0.410764   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  1.960850  0.816227   0.050390
# std    1.581139  0.113068  0.013771   0.446376
# min    0.000000  1.814096  0.796745  -0.410764
# 25%    1.000000  1.937035  0.812663  -0.371466
# 50%    2.000000  1.958331  0.812780   0.128670
# 75%    3.000000  1.963587  0.828171   0.257237
# max    4.000000  2.131202  0.830779   0.648275
# 3/3 Correction with CA: False
# Cross-validating...
# done.
# n =  67 mean age =  73.84 5.77
# Bias between chronological age and BPAD eliminated: True (r = 0.11656517143703787 p = 0.34753628284242377 )
# Cross-validating...
# done.
# n =  74 mean age =  74.04 5.66
# Bias between chronological age and BPAD eliminated: True (r = 0.1981975911437737 p = 0.09049900416751483 )
# Cross-validating...
# done.
# n =  72 mean age =  73.92 6.0
# Bias between chronological age and BPAD eliminated: True (r = -0.0830364167547011 p = 0.4880240391198276 )
# Cross-validating...
# done.
# n =  73 mean age =  73.64 5.89
# Bias between chronological age and BPAD eliminated: True (r = 0.04499154295697893 p = 0.7054568885924848 )
# Cross-validating...
# done.
# n =  71 mean age =  73.54 6.06
# Bias between chronological age and BPAD eliminated: True (r = -0.10744948551171168 p = 0.37244611956969254 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  7.777878 -1.707168   2.365896   svm
# 1      1  7.464654 -2.171928   1.058481   svm
# 2      2  6.676702 -1.041480   0.443507   svm
# 3      3  8.112380 -2.195580  -1.534677   svm
# 4      4  7.123389 -1.239010  -1.494147   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  7.431000 -1.671033   0.167812
# std    1.581139  0.558866  0.526861   1.685337
# min    0.000000  6.676702 -2.195580  -1.534677
# 25%    1.000000  7.123389 -2.171928  -1.494147
# 50%    2.000000  7.464654 -1.707168   0.443507
# 75%    3.000000  7.777878 -1.239010   1.058481
# max    4.000000  8.112380 -1.041480   2.365896
# {'None_model': 'Model', 'None_MAE': 'MAE', 'None_R2': 'R2', 'True_model': 'Model', 'True_MAE': 'MAE', 'True_R2': 'R2', 'False_model': 'Model', 'False_MAE': 'MAE', 'False_R2': 'R2'}

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality)
# Out:
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.0385277327476574, R2: 0.8021757276949517
# n =  67 mean age =  73.84 5.77
# Bias between chronological age and BPAD eliminated: True (r = 0.11656517143703751 p = 0.3475362828424253 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.8983420875795733, R2: 0.8392546825546279
# n =  74 mean age =  74.04 5.66
# Bias between chronological age and BPAD eliminated: True (r = 0.19819759114377367 p = 0.09049900416751483 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.039507026367528, R2: 0.8107822104742723
# n =  72 mean age =  73.92 6.0
# Bias between chronological age and BPAD eliminated: True (r = -0.08303641675470172 p = 0.4880240391198243 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.7641544213924782, R2: 0.8523237252713345
# n =  73 mean age =  73.64 5.89
# Bias between chronological age and BPAD eliminated: True (r = 0.044991542956979436 p = 0.7054568885924817 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.9450057598394248, R2: 0.8113968168365705
# n =  71 mean age =  73.54 6.06
# Bias between chronological age and BPAD eliminated: True (r = -0.10744948551171314 p = 0.3724461195696861 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.131202  0.796745   0.648275   svm
# 1      1  1.814096  0.812663   0.257237   svm
# 2      2  1.937035  0.828171   0.128670   svm
# 3      3  1.963587  0.812780  -0.371466   svm
# 4      4  1.958331  0.830779  -0.410764   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  1.960850  0.816227   0.050390
# std    1.581139  0.113068  0.013771   0.446376
# min    0.000000  1.814096  0.796745  -0.410764
# 25%    1.000000  1.937035  0.812663  -0.371466
# 50%    2.000000  1.958331  0.812780   0.128670
# 75%    3.000000  1.963587  0.828171   0.257237
# max    4.000000  2.131202  0.830779   0.648275

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality)
# Out:
# ---OASIS-MRI---
# n =  52 mean age =  70.65 4.25
# Bias between chronological age and BPAD eliminated: True (r = -0.2329969719405755 p = 0.09645510361216539 )
# Bias between chronological age and BPAD eliminated: True (r = -0.22133001450734952 p = 0.11482725207398994 )
# Bias between chronological age and BPAD eliminated: True (r = -0.25666380555590135 p = 0.06624831306050838 )
# Bias between chronological age and BPAD eliminated: True (r = -0.23915762638344185 p = 0.08772093517211034 )
# Bias between chronological age and BPAD eliminated: True (r = -0.23785420582736339 p = 0.08951522227903519 )
#
# ---BAGGED RESULTS---
# MAE:  2.230055816137234
# R2 Score:  0.5929167861543274
# Mean error:  -0.7118584797517225
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.317885  0.558132  -0.797654
# 1  2.040695  0.667064  -0.626197
# 2  2.462271  0.506024  -0.718589
# 3  2.089472  0.641534  -0.735328
# 4  2.436832  0.514644  -0.681523
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.269431  0.577480  -0.711858
# std    0.195105  0.073411   0.063669
# min    2.040695  0.506024  -0.797654
# 25%    2.089472  0.514644  -0.735328
# 50%    2.317885  0.558132  -0.718589
# 75%    2.436832  0.641534  -0.681523
# max    2.462271  0.667064  -0.626197

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality)
# Out:
# ---ADNI-MRI---
# n =  596 mean age =  73.18 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.1333998633442125 p = 0.001096690154698425 )
# n =  596 mean age =  73.18 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.1685649464511832 p = 3.531220338303036e-05 )
# n =  596 mean age =  73.18 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.09398756543870374 p = 0.02174495684870716 )
# n =  596 mean age =  73.18 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.13839549431175818 p = 0.0007043307121101381 )
# n =  596 mean age =  73.18 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.11991443883971988 p = 0.0033686846077760676 )
#
# ---BAGGED RESULTS---
# MAE:  2.618254994073226
# R2 Score:  0.7725961454203707
# Mean error:  1.5059176811472232
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.756800  0.750522   1.692365
# 1  2.572540  0.781027   1.455419
# 2  2.741265  0.752797   1.523678
# 3  2.409545  0.805955   1.232818
# 4  2.756701  0.748292   1.625308
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.647370  0.767719   1.505918
# std    0.154033  0.025174   0.177810
# min    2.409545  0.748292   1.232818
# 25%    2.572540  0.750522   1.455419
# 50%    2.741265  0.752797   1.523678
# 75%    2.756701  0.781027   1.625308
# max    2.756800  0.805955   1.692365

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from DELCODE

# %%
main("predict DELCODE MCI", modality)
# Out:
# ---DELCODE-MRI---
# n =  80 mean age =  73.41 5.83
# Bias between chronological age and BPAD eliminated: True (r = 0.029677049906932877 p = 0.7938461114106191 )
# Bias between chronological age and BPAD eliminated: True (r = 0.0810082149731644 p = 0.47502236958682575 )
# Bias between chronological age and BPAD eliminated: True (r = -0.046796378027484736 p = 0.6801943245323336 )
# Bias between chronological age and BPAD eliminated: True (r = 0.008516477418338586 p = 0.9402336719417634 )
# Bias between chronological age and BPAD eliminated: True (r = 0.01851133084430557 p = 0.8705353786171186 )
#
# ---BAGGED RESULTS---
# MAE:  2.6217382573253687
# R2 Score:  0.6756513941895171
# Mean error:  1.421507654884302
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.825056  0.627942   1.661884
# 1  2.535329  0.690911   1.392808
# 2  2.674572  0.667625   1.182504
# 3  2.457745  0.719602   1.154625
# 4  2.848418  0.624186   1.715718
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.668224  0.666053   1.421508
# std    0.172532  0.040906   0.261492
# min    2.457745  0.624186   1.154625
# 25%    2.535329  0.627942   1.182504
# 50%    2.674572  0.667625   1.392808
# 75%    2.825056  0.690911   1.661884
# max    2.848418  0.719602   1.715718

# %% [markdown]
# ## Association with cognitive performance in CN
# First predict age for all CN (excluding outliers) in cross-validated manner, then correlate with test scores and pathology.

# %%
main(5.1, modality)

# %% [markdown]
# ## Association with neuropathology in CN

# %%
main(5.2, modality)

# %% [markdown]
# ## Association with cognitive performance in MCI

# %%
main(5.3, modality)
# Out:
# Model BAGGED

# %% [markdown]
# ## Association with neuropathology in MCI

# %%
main(5.4, modality)
# Out:
# Model BAGGED
