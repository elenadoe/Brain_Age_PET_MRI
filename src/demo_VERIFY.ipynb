# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 6 - generate cross-validated predictions for whole dataset\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'PET'
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, rand_seed=0)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, rand_seed=0)
# Out:
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.4588202569072317, R2: 0.7285958956135092
# n =  67 mean age =  73.93 5.74
# Bias between chronological age and BPAD eliminated: True (r = -0.1378671957870084 p = 0.2658899582019034 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.2297887678798523, R2: 0.7746823866235167
# Kernel not linear, no weight coefficients available.
# n =  74 mean age =  74.08 5.7
# Bias between chronological age and BPAD eliminated: True (r = 0.006918749421799996 p = 0.9533465782449202 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.5412776342749273, R2: 0.7101181867541346
# n =  72 mean age =  73.9 6.08
# Bias between chronological age and BPAD eliminated: True (r = -0.029584353343996096 p = 0.8051465051493201 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.2734766563184188, R2: 0.7693435947625599
# n =  73 mean age =  73.7 5.87
# Bias between chronological age and BPAD eliminated: True (r = 0.17733811769231453 p = 0.13336840024976188 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.1801145366200414, R2: 0.75686736925233
# n =  71 mean age =  73.52 6.09
# Bias between chronological age and BPAD eliminated: True (r = 0.19397192143241437 p = 0.10504757197030025 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.791495  0.633610   0.653651   svm
# 1      1  2.867358  0.644160  -0.857504   svm
# 2      2  2.525409  0.764197   0.738626   svm
# 3      3  2.462794  0.684185  -0.576457   svm
# 4      4  2.510272  0.740570   0.034042   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  2.631466  0.693345  -0.001528
# std    1.581139  0.184147  0.057710   0.714421
# min    0.000000  2.462794  0.633610  -0.857504
# 25%    1.000000  2.510272  0.644160  -0.576457
# 50%    2.000000  2.525409  0.684185   0.034042
# 75%    3.000000  2.791495  0.740570   0.653651
# max    4.000000  2.867358  0.764197   0.738626

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality)
# Out:
# ---OASIS-PET---
# n =  52 mean age =  71.81 4.26
# Bias between chronological age and BPAD eliminated: True (r = 0.165690575395788 p = 0.24043416767831485 )
# Bias between chronological age and BPAD eliminated: True (r = 0.2075058171506761 p = 0.13991945990507546 )
# Bias between chronological age and BPAD eliminated: True (r = 0.20171640964772572 p = 0.15156478879458743 )
# Bias between chronological age and BPAD eliminated: True (r = 0.265784558367223 p = 0.0568556853611437 )
# Bias between chronological age and BPAD eliminated: False (r = 0.33028598249260244 p = 0.016785921069983424 )
#
# ---BAGGED RESULTS---
# MAE:  2.0349135405808685
# R2 Score:  0.6173524069654426
# Mean error:  -0.04165991842460288
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.482114  0.401417   0.092488
# 1  2.526906  0.489815  -0.716482
# 2  2.307645  0.523179   0.340423
# 3  2.204973  0.549734  -0.088747
# 4  2.366475  0.500293   0.164018
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.377623  0.492888  -0.041660
# std    0.130416  0.056081   0.407397
# min    2.204973  0.401417  -0.716482
# 25%    2.307645  0.489815  -0.088747
# 50%    2.366475  0.500293   0.092488
# 75%    2.482114  0.523179   0.164018
# max    2.526906  0.549734   0.340423

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment patients from DELCODE

# %%
main("predict DELCODE SCD", modality)
# Out:
# ---DELCODE-PET---
# n =  88 mean age =  70.9 5.54
# Bias between chronological age and BPAD eliminated: True (r = 0.09491010878303309 p = 0.3790796693314957 )
# Bias between chronological age and BPAD eliminated: True (r = 0.022354861445363743 p = 0.8362171686810642 )
# Bias between chronological age and BPAD eliminated: True (r = 0.0993028327507496 p = 0.3573107150509157 )
# Bias between chronological age and BPAD eliminated: False (r = 0.24488059865694903 p = 0.02147841143268938 )
# Bias between chronological age and BPAD eliminated: False (r = 0.3064461562359434 p = 0.003686338817482733 )
#
# ---BAGGED RESULTS---
# MAE:  2.637012920426293
# R2 Score:  0.641448869884131
# Mean error:  2.0699151776640523
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.929133  0.568203   2.258940
# 1  3.027326  0.584309   1.509532
# 2  3.236664  0.488028   2.599980
# 3  2.665847  0.653178   1.822240
# 4  2.920640  0.564744   2.158884
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.955922  0.571693   2.069915
# std    0.206168  0.058863   0.418326
# min    2.665847  0.488028   1.509532
# 25%    2.920640  0.564744   1.822240
# 50%    2.929133  0.568203   2.158884
# 75%    3.027326  0.584309   2.258940
# max    3.236664  0.653178   2.599980

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality)
# Out:
# ---ADNI-PET---
# n =  596 mean age =  73.22 6.93
# Bias between chronological age and BPAD eliminated: False (r = 0.19578351149360598 p = 1.4621688333892846e-06 )
# n =  596 mean age =  73.22 6.93
# Bias between chronological age and BPAD eliminated: False (r = 0.11341603417659413 p = 0.005571739020765683 )
# n =  596 mean age =  73.22 6.93
# Bias between chronological age and BPAD eliminated: False (r = 0.2386945065763347 p = 3.623116993114377e-09 )
# n =  596 mean age =  73.22 6.93
# Bias between chronological age and BPAD eliminated: False (r = 0.31640742244978043 p = 2.5236685380057033e-15 )
# n =  596 mean age =  73.22 6.93
# Bias between chronological age and BPAD eliminated: False (r = 0.3340880616656767 p = 5.2477154144677636e-17 )
#
# ---BAGGED RESULTS---
# MAE:  2.508842748753865
# R2 Score:  0.7936796123618025
# Mean error:  1.0694764950723272
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.800439  0.730835   1.082558
# 1  2.409120  0.815843   0.713145
# 2  2.784709  0.734349   1.121946
# 3  2.661806  0.752304   0.923261
# 4  2.952395  0.703747   1.506473
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.721694  0.747415   1.069476
# std    0.202906  0.042008   0.292507
# min    2.409120  0.703747   0.713145
# 25%    2.661806  0.730835   0.923261
# 50%    2.784709  0.734349   1.082558
# 75%    2.800439  0.752304   1.121946
# max    2.952395  0.815843   1.506473

# %% [markdown]
# ## Association with cognitive performance in CN
# First predict age for all CN (excluding outliers) in cross-validated manner, then correlate with test scores and pathology.

# %%
main(5.1, modality)

# %% [markdown]
# ## Association with neuropathology in CN

# %%
main(5.2, modality)

# %% [markdown]
# ## Association with cognitive performance in MCI

# %%
main(5.3, modality)
# Out:
# Model BAGGED

# %% [markdown]
# ## Association with neuropathology in MCI

# %%
main(5.4, modality)
# Out:
# Model BAGGED
