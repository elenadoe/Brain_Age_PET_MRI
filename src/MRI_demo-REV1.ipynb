# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'MRI'
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'Sch_Tian')
# Out:
# 1/3 Correction with CA: None
# n =  52 mean age =  74.65 5.1
# Bias between chronological age and BPAD eliminated: False (r = -0.6418592384373965 p = 2.9266013163494974e-07 )
# Bias between chronological age and BPAD eliminated: False (r = -0.7324309097503753 p = 6.774291311522928e-10 )
# Bias between chronological age and BPAD eliminated: False (r = -0.9194603417544195 p = 9.903089628480014e-23 )
# Bias between chronological age and BPAD eliminated: False (r = -0.9331220203296448 p = 7.373503578916731e-24 )
# Bias between chronological age and BPAD eliminated: False (r = -0.8845301232915247 p = 1.6371307115633163e-17 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  4.248169 -0.098846  -0.019552   rvr
# 1      1  4.012233  0.230892  -1.072837   rvr
# 2      2  4.525705  0.227978  -0.325126   svm
# 3      3  4.076096  0.316012   0.434816   svm
# 4      4  4.099383  0.362946  -0.102831   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  4.192317  0.207796  -0.217106
# std    1.581139  0.205452  0.180798   0.552502
# min    0.000000  4.012233 -0.098846  -1.072837
# 25%    1.000000  4.076096  0.227978  -0.325126
# 50%    2.000000  4.099383  0.230892  -0.102831
# 75%    3.000000  4.248169  0.316012  -0.019552
# max    4.000000  4.525705  0.362946   0.434816
# 2/3 Correction with CA: True
# n =  52 mean age =  74.65 5.1
# Bias between chronological age and BPAD eliminated: True (r = -0.10871038340172165 p = 0.4429964683239602 )
# Bias between chronological age and BPAD eliminated: True (r = 0.013994902047480657 p = 0.9215589302829239 )
# Bias between chronological age and BPAD eliminated: True (r = -0.11519802747713924 p = 0.40682833031399124 )
# Bias between chronological age and BPAD eliminated: True (r = 0.057902109410276174 p = 0.6834715474539237 )
# Bias between chronological age and BPAD eliminated: True (r = 0.2155469889143225 p = 0.1327536308757637 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.205722  0.710935  -0.340195   svm
# 1      1  1.808142  0.845333  -0.626225   svm
# 2      2  1.717322  0.879299  -0.080700   svm
# 3      3  1.360481  0.911752   0.076852   svm
# 4      4  1.941580  0.852192   0.301278   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  1.806649  0.839902  -0.133798
# std    1.581139  0.310046  0.076693   0.361098
# min    0.000000  1.360481  0.710935  -0.626225
# 25%    1.000000  1.717322  0.845333  -0.340195
# 50%    2.000000  1.808142  0.852192  -0.080700
# 75%    3.000000  1.941580  0.879299   0.076852
# max    4.000000  2.205722  0.911752   0.301278
# 3/3 Correction with CA: False
# n =  52 mean age =  74.65 5.1
# Bias between chronological age and BPAD eliminated: True (r = -0.01106442786988469 p = 0.9379477529662354 )
# Bias between chronological age and BPAD eliminated: True (r = 0.1395652216713297 p = 0.32374342286044366 )
# Bias between chronological age and BPAD eliminated: True (r = -0.11519802747713902 p = 0.40682833031399235 )
# Bias between chronological age and BPAD eliminated: True (r = 0.057902109410276605 p = 0.6834715474539214 )
# Bias between chronological age and BPAD eliminated: True (r = 0.21554698891432153 p = 0.13275363087576555 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  9.701618 -4.725138   0.296934   rvr
# 1      1  9.467022 -3.216478  -1.557200   rvr
# 2      2  7.354496 -1.213675  -0.345600   svm
# 3      3  6.362506 -0.930092   0.359412   svm
# 4      4  9.158395 -2.288703   1.421122   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  8.408807 -2.474817   0.034933
# std    1.581139  1.470713  1.551233   1.092605
# min    0.000000  6.362506 -4.725138  -1.557200
# 25%    1.000000  7.354496 -3.216478  -0.345600
# 50%    2.000000  9.158395 -2.288703   0.296934
# 75%    3.000000  9.467022 -1.213675   0.359412
# max    4.000000  9.701618 -0.930092   1.421122
# {'None_model': 'Model', 'None_MAE': 'MAE', 'None_R2': 'R2', 'True_model': 'Model', 'True_MAE': 'MAE', 'True_R2': 'R2', 'False_model': 'Model', 'False_MAE': 'MAE', 'False_R2': 'R2'}

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'Sch_Tian')
# Out:
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.9213304544420042, R2: 0.8263157672854485
# n =  52 mean age =  74.65 5.1
# Bias between chronological age and BPAD eliminated: True (r = -0.10871038340172165 p = 0.4429964683239602 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.168838247969348, R2: 0.7618520436804287
# Bias between chronological age and BPAD eliminated: True (r = 0.013994902047480657 p = 0.9215589302829239 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.6733952667691365, R2: 0.859260371710548
# Bias between chronological age and BPAD eliminated: True (r = -0.11519802747713924 p = 0.40682833031399124 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.8226309637632871, R2: 0.8358498922891567
# Bias between chronological age and BPAD eliminated: True (r = 0.057902109410276174 p = 0.6834715474539237 )
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 1.7817002359876617, R2: 0.8447270313178155
# Bias between chronological age and BPAD eliminated: True (r = 0.2155469889143225 p = 0.1327536308757637 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.205722  0.710935  -0.340195   svm
# 1      1  1.808142  0.845333  -0.626225   svm
# 2      2  1.717322  0.879299  -0.080700   svm
# 3      3  1.360481  0.911752   0.076852   svm
# 4      4  1.941580  0.852192   0.301278   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  1.806649  0.839902  -0.133798
# std    1.581139  0.310046  0.076693   0.361098
# min    0.000000  1.360481  0.710935  -0.626225
# 25%    1.000000  1.717322  0.845333  -0.340195
# 50%    2.000000  1.808142  0.852192  -0.080700
# 75%    3.000000  1.941580  0.879299   0.076852
# max    4.000000  2.205722  0.911752   0.301278

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'Sch_Tian')
# Out:
# ---OASIS-MRI---
# Using existing data.
# T-test age ADNI CN - OASIS CN: 0.002733100385750426
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IQR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-56b908b5a74f> in <module>
# ----> 1 main("predict OASIS CN", modality, 'Sch_Tian')
#
# /media/projects/brain_age_ELENA/PET_MRI_age/src/brain_age_main.py in main(analyze, modality, atlas, rand_seed)
#      83             "group not recognized"
#      84
# ---> 85         predict_other(database=database, group=group, modality=modality,
#      86                       atlas=atlas)
#      87         if database == "ADNI":
#
# /media/projects/brain_age_ELENA/PET_MRI_age/src/steps_of_analysis.py in predict_other(database, group, modality, atlas, info_init)
#     622
#     623         nooutliers_all.append(
# --> 624             file_.name[file_['AGE_CHECK'] & file_['IQR']].values.tolist())
#     625
#     626     # for bagging, only consider data that is not an outlier in any of the
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'IQR'

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment patients from ADNI

# %%
main("predict ADNI SMC", modality, 'Sch_Tian')

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'Sch_Tian')

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from DELCODE

# %%
main("predict DELCODE MCI", modality, 'Sch_Tian')
