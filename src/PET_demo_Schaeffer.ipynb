# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'PET'
feat_sel = False
check_outliers = True
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# Considering 216 ROIs before feature selection (Feature selection applied: False).
# First column: 17Networks_LH_VisCent_ExStr_1 (should be 'X17Networks_LH_VisCent_ExStr_1')
# Last column: CAU-lh (should be 'CAU-lh)
# 2 individuals younger than 60 years discarded.
# 185
# Total participants:  185 Inside IQR of all regions:  171
# (14 participants discarded as outliers)
# Outliers in train set:  12 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.2595321344428507, R2: 0.790375815320608
# Uncorrected: MAE RVR:  4.430108040593049 MAE SVM:  4.124879392961071
# n =  35 mean age =  74.0 6.82
# Bias between chronological age and BPAD eliminated: True (r = -0.0702048911061865 p = 0.6886050037325049 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  10 Outliers in test set:  1
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 3.182406593161051, R2: 0.5597011014179826
# Uncorrected: MAE RVR:  4.128611839225336 MAE SVM:  4.596761292294289
# Bias between chronological age and BPAD eliminated: True (r = -0.05454575112675811 p = 0.7520330702999005 )
# 185
# Total participants:  185 Inside IQR of all regions:  173
# (12 participants discarded as outliers)
# Outliers in train set:  10 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.946214607252515, R2: 0.655647622394455
# Uncorrected: MAE RVR:  4.345758134885363 MAE SVM:  4.365180984457255
# Bias between chronological age and BPAD eliminated: True (r = 0.15754452716035397 p = 0.3660700511297086 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  3
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.424841455773092, R2: 0.7578139614935792
# Uncorrected: MAE RVR:  4.215130313716138 MAE SVM:  4.129380665843351
# Bias between chronological age and BPAD eliminated: False (r = -0.41664863205906105 p = 0.014237726829489209 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  4
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.6864212327480814, R2: 0.6824152452626279
# Uncorrected: MAE RVR:  4.623290768831244 MAE SVM:  4.5977577114506705
# Bias between chronological age and BPAD eliminated: True (r = 0.30872183013935856 p = 0.08045088048196865 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  1.816055  0.892974  -0.575795   svm
# 1      1  3.089630  0.497252  -0.764262   rvr
# 2      2  3.326696  0.408459   1.011153   rvr
# 3      3  2.456090  0.782796   0.255724   svm
# 4      4  1.999927  0.859598  -0.713996   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  2.537680  0.688216  -0.157435
# std    1.581139  0.660260  0.220779   0.772872
# min    0.000000  1.816055  0.408459  -0.764262
# 25%    1.000000  1.999927  0.497252  -0.713996
# 50%    2.000000  2.456090  0.782796  -0.575795
# 75%    3.000000  3.089630  0.859598   0.255724
# max    4.000000  3.326696  0.892974   1.011153

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---OASIS-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.01171912681936003
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.013122305047633795
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.01290108855216487
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.012683313786573495
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.01714769751854313
# n =  59 mean age =  71.66 4.12
# Bias between chronological age and BPAD eliminated: True (r = 0.09477266475504921 p = 0.47522930195090274 )
# Bias between chronological age and BPAD eliminated: True (r = 0.18377144185502597 p = 0.1635377979264724 )
# Bias between chronological age and BPAD eliminated: True (r = 0.14737768576153137 p = 0.26532029225849585 )
# Bias between chronological age and BPAD eliminated: True (r = 0.1601978771613039 p = 0.22550420800806795 )
# Bias between chronological age and BPAD eliminated: True (r = 0.1287336317751569 p = 0.3311919238985733 )
#
# ---BAGGED RESULTS---
# MAE:  2.4452890899866926
# R2 Score:  0.4498975259922815
# Mean error:  -0.9282357398395605
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.587450  0.379777  -1.511857
# 1  2.958244  0.226078  -0.371031
# 2  3.191020  0.190487  -0.530353
# 3  2.556245  0.348762  -0.655810
# 4  2.631189  0.375140  -1.572128
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.784830  0.304049  -0.928236
# std    0.278334  0.089112   0.569696
# min    2.556245  0.190487  -1.572128
# 25%    2.587450  0.226078  -1.511857
# 50%    2.631189  0.348762  -0.655810
# 75%    2.958244  0.375140  -0.530353
# max    3.191020  0.379777  -0.371031

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment individuals from ADNI

# %%
main("predict ADNI SMC", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.03960154606030731
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04129671256269167
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.040536899078410175
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.03978944123824142
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.05841154014297311
# n =  102 mean age =  72.31 5.57
# Bias between chronological age and BPAD eliminated: True (r = -0.10003506691438585 p = 0.31713386777400804 )
# Bias between chronological age and BPAD eliminated: True (r = -0.12338091861542765 p = 0.21666108194297243 )
# Bias between chronological age and BPAD eliminated: True (r = 0.0381692299381956 p = 0.7032936471945211 )
# Bias between chronological age and BPAD eliminated: True (r = -0.12767525295520132 p = 0.20096555346556605 )
# Bias between chronological age and BPAD eliminated: True (r = -0.10485742416025404 p = 0.29424674892753483 )
#
# ---BAGGED RESULTS---
# MAE:  2.4485833462542494
# R2 Score:  0.7056436039597138
# Mean error:  0.1416001839186582
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.234289  0.739492  -0.059926
# 1  3.218904  0.505220  -0.098281
# 2  3.114313  0.537704   0.247410
# 3  2.556437  0.679858   0.477901
# 4  2.248896  0.750837   0.140897
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.674568  0.642622   0.141600
# std    0.468688  0.114420   0.235823
# min    2.234289  0.505220  -0.098281
# 25%    2.248896  0.537704  -0.059926
# 50%    2.556437  0.679858   0.140897
# 75%    3.114313  0.739492   0.247410
# max    3.218904  0.750837   0.477901

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.2630236112605444
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.25605435071057014
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.25163455529010015
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24726915601552146
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.36579515683323804
# n =  595 mean age =  73.21 6.93
# Bias between chronological age and BPAD eliminated: True (r = 0.04868071327173626 p = 0.23575809767602882 )
# Bias between chronological age and BPAD eliminated: True (r = -0.011660310293476372 p = 0.776535238472078 )
# Bias between chronological age and BPAD eliminated: False (r = 0.10273327062093969 p = 0.01216570074661723 )
# Bias between chronological age and BPAD eliminated: True (r = -0.04638021999620312 p = 0.2586599719625039 )
# Bias between chronological age and BPAD eliminated: True (r = -0.006204116004400927 p = 0.8799616183838255 )
#
# ---BAGGED RESULTS---
# MAE:  2.4130752122350607
# R2 Score:  0.8033587196473269
# Mean error:  0.42142006665149884
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.251506  0.827991   0.156616
# 1  3.310451  0.636869  -0.056391
# 2  3.145108  0.679855   1.072515
# 3  2.604088  0.773488   0.726678
# 4  2.294475  0.822864   0.207682
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.721126  0.748213   0.421420
# std    0.485627  0.086091   0.464008
# min    2.251506  0.636869  -0.056391
# 25%    2.294475  0.679855   0.156616
# 50%    2.604088  0.773488   0.207682
# 75%    3.145108  0.822864   0.726678
# max    3.310451  0.827991   1.072515

# %% [markdown]
# ## Assessment of brain age in subjective cognitive decline patients from DELCODE

# %%
main("predict DELCODE SMC", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---DELCODE-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0002879804967142233
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0003448612651428469
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.00033646212718089927
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0003282583702996834
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0005017499115563288
# n =  88 mean age =  70.93 5.53
# Bias between chronological age and BPAD eliminated: True (r = 0.08857918204964635 p = 0.41182844106534966 )
# Bias between chronological age and BPAD eliminated: True (r = 0.0407324820525701 p = 0.706324053008645 )
# Bias between chronological age and BPAD eliminated: True (r = 0.11079819950267426 p = 0.3040974615424949 )
# Bias between chronological age and BPAD eliminated: True (r = 0.03176901518885139 p = 0.7688856794467951 )
# Bias between chronological age and BPAD eliminated: True (r = 0.028629799787312407 p = 0.791174710760917 )
#
# ---BAGGED RESULTS---
# MAE:  2.530868054034995
# R2 Score:  0.6514033221563952
# Mean error:  1.592218681816861
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.265031  0.747923  -0.419747
# 1  3.552226  0.337253   0.527323
# 2  4.121593  0.204955   3.622028
# 3  3.253820  0.457667   2.682872
# 4  2.654559  0.640349   1.548617
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.169446  0.477629   1.592219
# std    0.732000  0.220222   1.619688
# min    2.265031  0.204955  -0.419747
# 25%    2.654559  0.337253   0.527323
# 50%    3.253820  0.457667   1.548617
# 75%    3.552226  0.640349   2.682872
# max    4.121593  0.747923   3.622028
