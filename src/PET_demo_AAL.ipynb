# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'PET'
feat_sel = False
check_outliers = True
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# Considering 90 ROIs before feature selection (Feature selection applied: False).
# First column: Precentral_L (should be 'Precentral_L')
# Last column: Temporal_Inf_R (should be 'Temporal_Inf_R')
# 2 individuals younger than 60 years discarded.
# 185
# Total participants:  185 Inside IQR of all regions:  175
# (10 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  3
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.637195321749037, R2: 0.6897542026304958
# Uncorrected: MAE RVR:  4.199601070419426 MAE SVM:  4.238305905941522
# n =  34 mean age =  73.71 6.82
# Bias between chronological age and BPAD eliminated: True (r = -0.10901524066160984 p = 0.5394006053083076 )
# 185
# Total participants:  185 Inside IQR of all regions:  175
# (10 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.5324627996926274, R2: 0.7330346429991597
# Uncorrected: MAE RVR:  3.947746791531408 MAE SVM:  4.10396898637427
# Bias between chronological age and BPAD eliminated: True (r = -0.10109665204001747 p = 0.5633597236069956 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  11 Outliers in test set:  0
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.6505312559266687, R2: 0.6838375409411626
# Uncorrected: MAE RVR:  4.193368618722599 MAE SVM:  4.2116502051594695
# Bias between chronological age and BPAD eliminated: True (r = 0.27781695207775803 p = 0.09594294063850478 )
# 185
# Total participants:  185 Inside IQR of all regions:  176
# (9 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  1
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.655909145785261, R2: 0.6787229661185782
# Uncorrected: MAE RVR:  3.954515870396919 MAE SVM:  4.411829929332872
# Bias between chronological age and BPAD eliminated: True (r = -0.2903993694019562 p = 0.08576912253982161 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  4
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.591878871332612, R2: 0.6984998996995593
# Uncorrected: MAE RVR:  4.416856640872934 MAE SVM:  4.489295380267604
# Bias between chronological age and BPAD eliminated: False (r = 0.5574582862627152 p = 0.0007511050871660674 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.375643  0.782822  -0.783351   rvr
# 1      1  2.628430  0.708076  -0.343309   rvr
# 2      2  3.140097  0.566783   1.133041   rvr
# 3      3  2.981253  0.545779  -0.103997   rvr
# 4      4  2.105924  0.792989  -0.396286   rvr
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  2.646269  0.679290  -0.098780
# std    1.581139  0.424738  0.117215   0.730471
# min    0.000000  2.105924  0.545779  -0.783351
# 25%    1.000000  2.375643  0.566783  -0.396286
# 50%    2.000000  2.628430  0.708076  -0.343309
# 75%    3.000000  2.981253  0.782822  -0.103997
# max    4.000000  3.140097  0.792989   1.133041

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---OASIS-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.2898353617340448e-05
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.7537566458736934e-05
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.7111210246627826e-05
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.669485135360612e-05
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 2.3236933222516583e-05
# n =  72 mean age =  70.12 5.04
# Bias between chronological age and BPAD eliminated: True (r = -0.1024501217642545 p = 0.3917985660340376 )
# Bias between chronological age and BPAD eliminated: True (r = -0.1745451308299082 p = 0.14253207208429752 )
# Bias between chronological age and BPAD eliminated: True (r = 0.0632021548869889 p = 0.5978949968837275 )
# Bias between chronological age and BPAD eliminated: True (r = -0.08715494050337913 p = 0.4666269354917487 )
# Bias between chronological age and BPAD eliminated: True (r = 0.05899382560155142 p = 0.622544444689707 )
#
# ---BAGGED RESULTS---
# MAE:  2.5674667582726616
# R2 Score:  0.6238791140700773
# Mean error:  0.7198744209926837
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.627317  0.573038   0.488245
# 1  2.762779  0.563811   1.844454
# 2  2.627028  0.605366   0.013384
# 3  3.135874  0.445104   1.284334
# 4  2.631663  0.614280  -0.031045
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.756932  0.560320   0.719874
# std    0.219658  0.067804   0.821577
# min    2.627028  0.445104  -0.031045
# 25%    2.627317  0.563811   0.013384
# 50%    2.631663  0.573038   0.488245
# 75%    2.762779  0.605366   1.284334
# max    3.135874  0.614280   1.844454

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment individuals from ADNI

# %%
main("predict ADNI SMC", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.03960154606030731
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04129671256269167
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.040536899078410175
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.03978944123824142
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.05841154014297311
# n =  102 mean age =  72.31 5.57
# Bias between chronological age and BPAD eliminated: True (r = -0.05057985932672808 p = 0.6136577976116324 )
# Bias between chronological age and BPAD eliminated: True (r = -0.15262719158779856 p = 0.12565852561702523 )
# Bias between chronological age and BPAD eliminated: True (r = -0.004409617544586815 p = 0.9649153334564976 )
# Bias between chronological age and BPAD eliminated: True (r = -0.11203741353543945 p = 0.26224069316633913 )
# Bias between chronological age and BPAD eliminated: True (r = 0.04010821542176244 p = 0.6889783618599553 )
#
# ---BAGGED RESULTS---
# MAE:  2.63347552652196
# R2 Score:  0.6522156159309567
# Mean error:  0.6229136776653025
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.698441  0.602909   0.751596
# 1  2.806354  0.622313   0.495508
# 2  2.977240  0.556757   0.695369
# 3  2.814700  0.601573   0.810760
# 4  2.524661  0.686618   0.361335
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.764279  0.614034   0.622914
# std    0.166895  0.047161   0.188249
# min    2.524661  0.556757   0.361335
# 25%    2.698441  0.601573   0.495508
# 50%    2.806354  0.602909   0.695369
# 75%    2.814700  0.622313   0.751596
# max    2.977240  0.686618   0.810760

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.2630236112605444
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.25605435071057014
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.25163455529010015
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24726915601552146
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.36579515683323804
# n =  595 mean age =  73.21 6.93
# Bias between chronological age and BPAD eliminated: True (r = 0.027214434926561778 p = 0.5076135574250609 )
# Bias between chronological age and BPAD eliminated: True (r = -0.05641823191035133 p = 0.16932079675651268 )
# Bias between chronological age and BPAD eliminated: False (r = 0.1135538733137418 p = 0.005553763424194028 )
# Bias between chronological age and BPAD eliminated: True (r = 0.023222138942549403 p = 0.5718466598373846 )
# Bias between chronological age and BPAD eliminated: False (r = 0.1506492399902822 p = 0.0002259606048210193 )
#
# ---BAGGED RESULTS---
# MAE:  2.7135434333835637
# R2 Score:  0.7483701125438997
# Mean error:  0.5637332170444044
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.838289  0.726522   0.786397
# 1  2.723353  0.742428   0.070917
# 2  3.046718  0.695074   0.999600
# 3  3.138399  0.656722   0.709869
# 4  2.750032  0.744799   0.251883
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.899358  0.713109   0.563733
# std    0.184296  0.037244   0.387632
# min    2.723353  0.656722   0.070917
# 25%    2.750032  0.695074   0.251883
# 50%    2.838289  0.726522   0.709869
# 75%    3.046718  0.742428   0.786397
# max    3.138399  0.744799   0.999600

# %% [markdown]
# ## Assessment of brain age in subjective cognitive decline patients from DELCODE

# %%
main("predict DELCODE SMC", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---DELCODE-PET---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0002879804967142233
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0003448612651428469
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.00033646212718089927
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0003282583702996834
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE SMC: 0.0005017499115563288
# n =  88 mean age =  70.93 5.53
# Bias between chronological age and BPAD eliminated: True (r = 0.03425846971782162 p = 0.7513415714218235 )
# Bias between chronological age and BPAD eliminated: True (r = -0.1214073020853535 p = 0.2598308096371282 )
# Bias between chronological age and BPAD eliminated: True (r = 0.08947872457579403 p = 0.4070773198053744 )
# Bias between chronological age and BPAD eliminated: True (r = -0.03559693352622279 p = 0.7419602245865611 )
# Bias between chronological age and BPAD eliminated: True (r = 0.07573922178834293 p = 0.4830868997171681 )
#
# ---BAGGED RESULTS---
# MAE:  3.2246963414151355
# R2 Score:  0.49480435124472566
# Mean error:  2.809806064165377
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.831307  0.616120   2.004416
# 1  3.165486  0.484715   2.806598
# 2  3.847096  0.329924   3.390895
# 3  3.685969  0.351078   3.167541
# 4  3.255531  0.474225   2.679580
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.357078  0.451212   2.809806
# std    0.409799  0.115741   0.531803
# min    2.831307  0.329924   2.004416
# 25%    3.165486  0.351078   2.679580
# 50%    3.255531  0.474225   2.806598
# 75%    3.685969  0.484715   3.167541
# max    3.847096  0.616120   3.390895
