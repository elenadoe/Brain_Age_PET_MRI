# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 6 - generate cross-validated predictions for whole dataset\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
import numpy as np
from brain_age_main import main
modality = 'PET'
rand_seed_np = np.random.RandomState(0)
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'AAL1_cropped', rand_seed_np=rand_seed_np)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'AAL1_cropped', rand_seed_np=rand_seed_np)
# Out:
# First column: Precentral_L (should be 'Precentral_L')
# Last column: Vermis_10 (should be 'Vermis_10')
# 2 individuals younger than 60 years discarded.
# Total participants:  276 Inside IQR of all regions:  264
# (12 participants discarded as outliers)
# Outliers in train set:  10 Outliers in test set:  2
# Total participants:  276 Inside IQR of all regions:  266
# (10 participants discarded as outliers)
# Outliers in train set:  9 Outliers in test set:  1
# Total participants:  276 Inside IQR of all regions:  265
# (11 participants discarded as outliers)
# Outliers in train set:  11 Outliers in test set:  0
# Total participants:  276 Inside IQR of all regions:  264
# (12 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  5
# Total participants:  276 Inside IQR of all regions:  258
# (18 participants discarded as outliers)
# Outliers in train set:  12 Outliers in test set:  6
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.078878301399694, R2: 0.8169053878585486
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-e9ac0d2bcc0f> in <module>
# ----> 1 main("predict ADNI CN", modality, 'AAL1_cropped', rand_seed_np=rand_seed_np)
#
# /media/projects/brain_age_ELENA/Brain_Age_PET_MRI/src/brain_age_main.py in main(analyze, modality, atlas, rand_seed_np, rand_seed)
#      69     elif analyze == "predict ADNI CN":
#      70         group = "CN"
# ---> 71         brain_age(dir_mri_csv, dir_pet_csv, modality, atlas=atlas,
#      72                   correct_with_CA='True',
#      73                   rand_seed=rand_seed,
#
# /media/projects/brain_age_ELENA/Brain_Age_PET_MRI/src/steps_of_analysis.py in brain_age(dir_mri_csv, dir_pet_csv, modality, rand_seed, atlas, database, correct_with_CA, cv_outer, cv_inner, info, info_init, save)
#     491             plots.plot_hist(df_test, group, mode, modality,
#     492                             df_test['Dataset'], y='age', atlas=atlas, r=r)
# --> 493             plots.feature_imp(df_test, col, final_model, final_model_name,
#     494                               modality, atlas=atlas, r=r, rand_seed=rand_seed)
#     495
#
# /media/projects/brain_age_ELENA/Brain_Age_PET_MRI/src/plots.py in feature_imp(df_test, col, final_model, final_model_name, modality, atlas, r, y, rand_seed)
#     363
#     364             # put feature importance into dataframe and save
# --> 365             df_imp = pd.DataFrame({'region': labels,
#     366                                    'feat_importance': imp})
#     367             df_imp.to_csv('../results/ADNI/CN/evaluation/' +
#
# UnboundLocalError: local variable 'labels' referenced before assignment

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'AAL3')  # TODO: pre-processing

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment patients from ADNI

# %%
...

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment patients from DELCODE

# %%
main("predict DELCODE SCD", modality, 'AAL3')

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'AAL3')
