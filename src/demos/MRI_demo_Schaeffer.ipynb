# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'MRI'
feat_sel = False
check_outliers = True
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# Considering 216 ROIs before feature selection (Feature selection applied: False).
# First column: 17Networks_LH_VisCent_ExStr_1 (should be 'X17Networks_LH_VisCent_ExStr_1')
# Last column: CAU-lh (should be 'CAU-lh)
# 2 individuals younger than 60 years discarded.
# 185
# Total participants:  185 Inside IQR of all regions:  171
# (14 participants discarded as outliers)
# Outliers in train set:  12 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.3484572009672693, R2: 0.7644004897316103
# Uncorrected: MAE RVR:  4.239786602613139 MAE SVM:  4.396879975184665
# n =  35 mean age =  74.0 6.76
# Bias between chronological age and BPAD eliminated: True (r = -0.07300637718006688 p = 0.67683739720184 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  10 Outliers in test set:  1
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.579570913627209, R2: 0.7179101214507615
# Uncorrected: MAE RVR:  4.434545737775254 MAE SVM:  4.572457758759652
# Bias between chronological age and BPAD eliminated: True (r = 0.04896446448744181 p = 0.7767256580510926 )
# 185
# Total participants:  185 Inside IQR of all regions:  173
# (12 participants discarded as outliers)
# Outliers in train set:  10 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.0355709444662575, R2: 0.8171261258912932
# Uncorrected: MAE RVR:  4.7709489579004325 MAE SVM:  4.698257458809417
# Bias between chronological age and BPAD eliminated: False (r = 0.45427103206321007 p = 0.006119498611154833 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  3
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.726324326966518, R2: 0.6871362504225609
# Uncorrected: MAE RVR:  4.3194280505075895 MAE SVM:  4.38054813272009
# Bias between chronological age and BPAD eliminated: True (r = -0.17230944273011828 p = 0.32982758639357224 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  4
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.560660241504519, R2: 0.7122954084985639
# Uncorrected: MAE RVR:  4.195987161305936 MAE SVM:  4.288714378648568
# Bias between chronological age and BPAD eliminated: True (r = -0.10903131724678843 p = 0.5458491084494811 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.440184  0.763699   0.116765   rvr
# 1      1  2.748485  0.635137  -0.715105   rvr
# 2      2  3.004116  0.563142   0.257705   svm
# 3      3  3.093404  0.570439  -0.676826   rvr
# 4      4  2.451256  0.779327   0.738180   rvr
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  2.747489  0.662349  -0.055856
# std    1.581139  0.303194  0.103665   0.628257
# min    0.000000  2.440184  0.563142  -0.715105
# 25%    1.000000  2.451256  0.570439  -0.676826
# 50%    2.000000  2.748485  0.635137   0.116765
# 75%    3.000000  3.004116  0.763699   0.257705
# max    4.000000  3.093404  0.779327   0.738180

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---OASIS-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 9.833961147824404e-05
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.00011709624746854897
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.00010320223050982285
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.00012070300660698707
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 0.00015586236749024152
# n =  59 mean age =  70.36 4.14
# Bias between chronological age and BPAD eliminated: True (r = -0.18007520554313078 p = 0.17232367446292066 )
# Bias between chronological age and BPAD eliminated: True (r = -0.1182638579124836 p = 0.37233828337989583 )
# Bias between chronological age and BPAD eliminated: True (r = -0.0008236689147743902 p = 0.9950600476269977 )
# Bias between chronological age and BPAD eliminated: True (r = -0.2303465719379609 p = 0.07923268068155566 )
# Bias between chronological age and BPAD eliminated: False (r = -0.2848171621738417 p = 0.02878508499516626 )
#
# ---BAGGED RESULTS---
# MAE:  2.691929222265099
# R2 Score:  0.2378100936622558
# Mean error:  0.28217483149022854
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.958978  0.133901   0.287646
# 1  2.964087  0.228466  -0.221805
# 2  3.320262  0.000920  -0.565855
# 3  3.397305 -0.156409   0.824887
# 4  2.884212  0.151882   1.086002
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.104969  0.071752   0.282175
# std    0.235428  0.151589   0.691710
# min    2.884212 -0.156409  -0.565855
# 25%    2.958978  0.000920  -0.221805
# 50%    2.964087  0.133901   0.287646
# 75%    3.320262  0.151882   0.824887
# max    3.397305  0.228466   1.086002

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment individuals from ADNI

# %%
main("predict ADNI SMC", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.044709890054517885
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04414258965708292
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04057984860669695
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04387822762077537
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.06312781296889218
# n =  102 mean age =  72.31 5.57
# Bias between chronological age and BPAD eliminated: True (r = 0.034713510372449685 p = 0.7290625371187733 )
# Bias between chronological age and BPAD eliminated: True (r = 0.13996716205473383 p = 0.1605887283963632 )
# Bias between chronological age and BPAD eliminated: False (r = 0.30149608707812453 p = 0.002074010742200492 )
# Bias between chronological age and BPAD eliminated: True (r = 0.016226495260950546 p = 0.8714078588412791 )
# Bias between chronological age and BPAD eliminated: True (r = -0.08556602683416667 p = 0.39249930735743344 )
#
# ---BAGGED RESULTS---
# MAE:  2.3713516828226022
# R2 Score:  0.7320442245064729
# Mean error:  -0.0036940223775575967
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.390479  0.723254   0.156059
# 1  2.572561  0.679924  -0.057264
# 2  2.759996  0.624758  -0.508978
# 3  2.812560  0.578220   0.080215
# 4  2.513695  0.689345   0.311498
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.609858  0.659100  -0.003694
# std    0.174925  0.057413   0.312286
# min    2.390479  0.578220  -0.508978
# 25%    2.513695  0.624758  -0.057264
# 50%    2.572561  0.679924   0.080215
# 75%    2.759996  0.689345   0.156059
# max    2.812560  0.723254   0.311498

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.261138350227997
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24503986691621527
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.22793070228500045
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24107245458332446
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.3523884275316941
# n =  595 mean age =  73.17 6.91
# Bias between chronological age and BPAD eliminated: False (r = 0.12991339377527678 p = 0.0014945870910705822 )
# Bias between chronological age and BPAD eliminated: False (r = 0.11602471329571176 p = 0.0046002220282626936 )
# Bias between chronological age and BPAD eliminated: False (r = 0.37723542515312075 p = 1.4698975929450147e-21 )
# Bias between chronological age and BPAD eliminated: True (r = 0.05030887570368862 p = 0.22043929845467436 )
# Bias between chronological age and BPAD eliminated: True (r = 0.02431118447136499 p = 0.5539483758637995 )
#
# ---BAGGED RESULTS---
# MAE:  3.7049996493395883
# R2 Score:  0.565335280320072
# Mean error:  2.338800354987322
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  3.683916  0.562434   2.389531
# 1  3.592309  0.585320   1.753254
# 2  4.202240  0.434104   2.419149
# 3  4.195445  0.440820   2.495779
# 4  3.795525  0.542779   2.636290
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.893887  0.513091   2.338800
# std    0.287546  0.070702   0.340968
# min    3.592309  0.434104   1.753254
# 25%    3.683916  0.440820   2.389531
# 50%    3.795525  0.542779   2.419149
# 75%    4.195445  0.562434   2.495779
# max    4.202240  0.585320   2.636290

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from DELCODE

# %%
main("predict DELCODE MCI", modality, 'Sch_Tian_1mm',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---DELCODE-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5896869315003055
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5738636647280029
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5525611169682811
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5697693081271962
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.6906552420226948
# n =  80 mean age =  73.41 5.83
# Bias between chronological age and BPAD eliminated: True (r = 0.03068502405767402 p = 0.7870069319792136 )
# Bias between chronological age and BPAD eliminated: True (r = 0.07187736830364441 p = 0.5263465531750537 )
# Bias between chronological age and BPAD eliminated: False (r = 0.2720191575042432 p = 0.014649120032762062 )
# Bias between chronological age and BPAD eliminated: True (r = -0.04231021505977005 p = 0.7094126619390948 )
# Bias between chronological age and BPAD eliminated: True (r = -0.052322813923152085 p = 0.6448416801646637 )
#
# ---BAGGED RESULTS---
# MAE:  3.5137058060186304
# R2 Score:  0.4093695418044866
# Mean error:  2.069234372699919
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  3.468818  0.456142   1.857311
# 1  3.857807  0.322322   2.240075
# 2  4.067034  0.228821   1.959709
# 3  4.228781  0.149613   2.783044
# 4  3.213770  0.507555   1.506033
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.767242  0.332891   2.069234
# std    0.420263  0.150193   0.477707
# min    3.213770  0.149613   1.506033
# 25%    3.468818  0.228821   1.857311
# 50%    3.857807  0.322322   1.959709
# 75%    4.067034  0.456142   2.240075
# max    4.228781  0.507555   2.783044
