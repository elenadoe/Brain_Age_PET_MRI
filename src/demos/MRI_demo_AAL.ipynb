# %% [markdown]
# # Demonstration of Analyses for "Comparison of Structural and Metabolic Biomarkers of Neurodegeneration for Brain Age Prediction"
#
# **Steps of Analysis:**\
# 1 - bias-correction\
# 2 - brain age prediction in cognitively normals (CN)\
# 2.1 - validation of brain age prediction in CN\
# 3 - brain age prediction in individuals with mild cognitive impairment (MCI)\
# 4 - association with cognitive performance/neuropathology
#
# Examplary demonstration for PET modality

# %%
from brain_age_main import main
modality = 'MRI'
feat_sel = False
check_outliers = True
# Out:
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Bias-correction
# Comparison of no bia-correction ('None'), correction with chronological age (CA, 'True'), and correction without CA ('False').

# %%
main("bias correction", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)

# %% [markdown]
# ## Main brain age prediction in cognitively normal individuals from ADNI

# %%
main("predict ADNI CN", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# Considering 90 ROIs before feature selection (Feature selection applied: False).
# First column: Precentral_L (should be 'Precentral_L')
# Last column: Temporal_Inf_R (should be 'Temporal_Inf_R')
# 2 individuals younger than 60 years discarded.
# 185
# Total participants:  185 Inside IQR of all regions:  175
# (10 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  3
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.5813184815972647, R2: 0.7093447229879264
# Uncorrected: MAE RVR:  4.258932567881408 MAE SVM:  4.608803302348226
# n =  34 mean age =  73.71 6.75
# Bias between chronological age and BPAD eliminated: True (r = -0.24347021213673747 p = 0.16527586104433103 )
# 185
# Total participants:  185 Inside IQR of all regions:  175
# (10 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  2
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.644218855745875, R2: 0.7088072429583093
# Uncorrected: MAE RVR:  4.1164431557810985 MAE SVM:  4.579148959722464
# Bias between chronological age and BPAD eliminated: True (r = -0.08627949856298399 p = 0.6221401891501958 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  11 Outliers in test set:  0
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.2126936460342166, R2: 0.7905251742207949
# Uncorrected: MAE RVR:  4.657967444839561 MAE SVM:  4.317440663240786
# Bias between chronological age and BPAD eliminated: False (r = 0.3352170514256095 p = 0.04254345196883704 )
# 185
# Total participants:  185 Inside IQR of all regions:  176
# (9 participants discarded as outliers)
# Outliers in train set:  8 Outliers in test set:  1
# Cross-validating...
# done.
# Significant association between  rvr -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): rvr
# MAE: 2.7599118134271707, R2: 0.6892159565526687
# Uncorrected: MAE RVR:  4.521535084798552 MAE SVM:  4.808933178390352
# Bias between chronological age and BPAD eliminated: True (r = 0.022941033525145215 p = 0.8943470132332394 )
# 185
# Total participants:  185 Inside IQR of all regions:  174
# (11 participants discarded as outliers)
# Outliers in train set:  7 Outliers in test set:  4
# Cross-validating...
# done.
# Significant association between  svm -predicted age delta and CA: True
# ---CROSS-VALIDATION---
#  Final model (smallest MAE): svm
# MAE: 2.2491343230312157, R2: 0.7860173537982662
# Uncorrected: MAE RVR:  4.936624354656068 MAE SVM:  4.432574088779246
# Bias between chronological age and BPAD eliminated: True (r = 0.046248571493841574 p = 0.7982826120907891 )
# ---TEST---
#    Round       MAE        R2  Mean diff Model
# 0      0  2.246867  0.805784   0.467193   rvr
# 1      1  2.773806  0.648726  -0.350815   rvr
# 2      2  2.708506  0.707814  -0.395383   svm
# 3      3  2.001886  0.822880   0.021350   rvr
# 4      4  2.733948  0.683800   0.643855   svm
#           Round       MAE        R2  Mean diff
# count  5.000000  5.000000  5.000000   5.000000
# mean   2.000000  2.493003  0.733801   0.077240
# std    1.581139  0.348254  0.076697   0.469799
# min    0.000000  2.001886  0.648726  -0.395383
# 25%    1.000000  2.246867  0.683800  -0.350815
# 50%    2.000000  2.708506  0.707814   0.021350
# 75%    3.000000  2.733948  0.805784   0.467193
# max    4.000000  2.773806  0.822880   0.643855

# %% [markdown]
# ## Validation of brain age prediction in cognitively normal individuals from OASIS

# %%
main("predict OASIS CN", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---OASIS-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.513815263580742e-08
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 2.1662578752489143e-08
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 1.8064915612266698e-08
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 2.313412488757301e-08
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - OASIS CN: 2.820416322369866e-08
# n =  72 mean age =  68.92 4.9
# Bias between chronological age and BPAD eliminated: True (r = -0.1852666384589042 p = 0.11922184587578154 )
# Bias between chronological age and BPAD eliminated: True (r = -0.1985422153812723 p = 0.09454579596401791 )
# Bias between chronological age and BPAD eliminated: True (r = -0.08179799657143984 p = 0.4945578010752125 )
# Bias between chronological age and BPAD eliminated: True (r = -0.14553876638396887 p = 0.22252879218684454 )
# Bias between chronological age and BPAD eliminated: True (r = -0.07186954039956024 p = 0.5485482832082315 )
#
# ---BAGGED RESULTS---
# MAE:  2.77996158233477
# R2 Score:  0.471987442729233
# Mean error:  -0.27890912238777726
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  3.228460  0.298054   0.105625
# 1  3.243223  0.327617  -0.156727
# 2  2.897237  0.448265  -0.858524
# 3  2.880629  0.440653   0.033548
# 4  3.076470  0.421483  -0.518467
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.065204  0.387214  -0.278909
# std    0.173746  0.069388   0.404279
# min    2.880629  0.298054  -0.858524
# 25%    2.897237  0.327617  -0.518467
# 50%    3.076470  0.421483  -0.156727
# 75%    3.228460  0.440653   0.033548
# max    3.243223  0.448265   0.105625

# %% [markdown]
# ## Assessment of brain age in subjective cognitive impairment individuals from ADNI

# %%
main("predict ADNI SMC", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.044709890054517885
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04414258965708292
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04057984860669695
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.04387822762077537
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI SMC: 0.06312781296889218
# n =  102 mean age =  72.31 5.57
# Bias between chronological age and BPAD eliminated: True (r = -0.1559103957535151 p = 0.11763057527877628 )
# Bias between chronological age and BPAD eliminated: True (r = -0.09057496681019941 p = 0.36527945751517144 )
# Bias between chronological age and BPAD eliminated: True (r = 0.03514952000844577 p = 0.7257938927724343 )
# Bias between chronological age and BPAD eliminated: True (r = -0.11894036486148585 p = 0.23378473768772456 )
# Bias between chronological age and BPAD eliminated: True (r = -0.001783761705612971 p = 0.9858039143849209 )
#
# ---BAGGED RESULTS---
# MAE:  2.4991714398047855
# R2 Score:  0.6890737363954107
# Mean error:  0.10481083043710437
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  2.861091  0.596840   0.283457
# 1  2.798533  0.605999   0.142133
# 2  2.400932  0.716922  -0.041281
# 3  2.641407  0.648943  -0.054361
# 4  2.689614  0.651722   0.194106
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   2.678315  0.644085   0.104811
# std    0.177687  0.047618   0.148290
# min    2.400932  0.596840  -0.054361
# 25%    2.641407  0.605999  -0.041281
# 50%    2.689614  0.648943   0.142133
# 75%    2.798533  0.651722   0.194106
# max    2.861091  0.716922   0.283457

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from ADNI

# %%
main("predict ADNI MCI", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---ADNI-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.261138350227997
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24503986691621527
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.22793070228500045
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.24107245458332446
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - ADNI MCI: 0.3523884275316941
# n =  595 mean age =  73.17 6.91
# Bias between chronological age and BPAD eliminated: True (r = 0.06124407312497675 p = 0.13565642729682176 )
# Bias between chronological age and BPAD eliminated: True (r = 0.03178563781419611 p = 0.43898982955390997 )
# Bias between chronological age and BPAD eliminated: False (r = 0.2007626300191994 p = 7.925916300306862e-07 )
# Bias between chronological age and BPAD eliminated: False (r = 0.1604493113827296 p = 8.457722709611882e-05 )
# Bias between chronological age and BPAD eliminated: False (r = 0.2031975540448161 p = 5.782736119103691e-07 )
#
# ---BAGGED RESULTS---
# MAE:  3.3007641254162507
# R2 Score:  0.6481271910620051
# Mean error:  2.1628356022639865
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  3.379112  0.627807   2.035562
# 1  3.315744  0.634290   1.949423
# 2  3.339422  0.639666   2.011231
# 3  3.149122  0.679310   1.807070
# 4  4.044712  0.473168   3.010892
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.445623  0.610848   2.162836
# std    0.346190  0.079546   0.482311
# min    3.149122  0.473168   1.807070
# 25%    3.315744  0.627807   1.949423
# 50%    3.339422  0.634290   2.011231
# 75%    3.379112  0.639666   2.035562
# max    4.044712  0.679310   3.010892

# %% [markdown]
# ## Assessment of brain age in mild cognitive impairment patients from DELCODE

# %%
main("predict DELCODE MCI", modality, 'AAL1_cropped',
    check_outliers=check_outliers, feat_sel=feat_sel)
# Out:
# ---DELCODE-MRI---
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5896869315003055
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5738636647280029
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5525611169682811
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.5697693081271962
# Detected 0 subjects younger than 60 who were removed.from analyses
# T-test age ADNI CN - DELCODE MCI: 0.6906552420226948
# n =  80 mean age =  73.41 5.83
# Bias between chronological age and BPAD eliminated: True (r = -0.14415250253935724 p = 0.20205391491456276 )
# Bias between chronological age and BPAD eliminated: True (r = -0.11400727527124661 p = 0.3139582866604728 )
# Bias between chronological age and BPAD eliminated: True (r = 0.039661885971651184 p = 0.7268633527233352 )
# Bias between chronological age and BPAD eliminated: True (r = -0.007584931575602714 p = 0.9467609002834314 )
# Bias between chronological age and BPAD eliminated: True (r = 0.11601342278595586 p = 0.30546242001336654 )
#
# ---BAGGED RESULTS---
# MAE:  3.6927769730577205
# R2 Score:  0.38263839096553853
# Mean error:  2.8876070644377916
#
# ---RESULTS ACROSS MODELS---
#         MAE        R2  mean_diff
# 0  3.576146  0.431925   2.510383
# 1  3.804533  0.338788   2.455432
# 2  3.665284  0.399255   2.408585
# 3  3.643806  0.429115   2.895570
# 4  4.831611 -0.081578   4.168065
#             MAE        R2  mean_diff
# count  5.000000  5.000000   5.000000
# mean   3.904276  0.303501   2.887607
# std    0.525007  0.218502   0.741312
# min    3.576146 -0.081578   2.408585
# 25%    3.643806  0.338788   2.455432
# 50%    3.665284  0.399255   2.510383
# 75%    3.804533  0.429115   2.895570
# max    4.831611  0.431925   4.168065
